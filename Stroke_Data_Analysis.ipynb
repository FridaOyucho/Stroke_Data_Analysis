# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading Data
df = pd.read_csv("stroke_data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# Checking last three rows
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
# Checking data types
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
# Cleaning data type 
df['age'] = df['age'].astype(int)
df['age'].dtypes
df['hypertension'] = df['hypertension'].astype(bool)
df['heart_disease'] = df['heart_disease'].astype(bool)
df['stroke'] = df['stroke'].astype(bool)
df.dtypes
# Out:
# id                     int64
# gender                object
# age                    int32
# hypertension            bool
# heart_disease           bool
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                  bool
# dtype: object

# %%
#Changing all characters to lowercase
df.columns= df.columns.str.lower()
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# Checking dimension of the dataset
df.shape
# Out:
# (5110, 12)

# %%
# Checking for missingness
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  residence_type  avg_glucose_level    bmi  smoking_status  \
# 0         False           False              False  False           False
# 1         False           False              False   True           False
# 2         False           False              False  False           False
# 3         False           False              False  False           False
# 4         False           False              False  False           False
# ...         ...             ...                ...    ...             ...
# 5105      False           False              False   True           False
# 5106      False           False              False  False           False
# 5107      False           False              False  False           False
# 5108      False           False              False  False           False
# 5109      False           False              False  False           False
#
#       stroke
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 5105   False
# 5106   False
# 5107   False
# 5108   False
# 5109   False
#
# [5110 rows x 12 columns]

# %%
# Checking sum of missingness in the columns
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Checking if any of the columns has  missing values and returns True if present and False if not
df.isna().any()
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# residence_type       False
# avg_glucose_level    False
# bmi                   True
# smoking_status       False
# stroke               False
# dtype: bool

# %%
# To check the summary statistics of the data
df.describe()
# Out:
#                  id          age  avg_glucose_level          bmi
# count   5110.000000  5110.000000        5110.000000  4909.000000
# mean   36517.829354    43.215264         106.147677    28.893237
# std    21161.721625    22.633866          45.283560     7.854067
# min       67.000000     0.000000          55.120000    10.300000
# 25%    17741.250000    25.000000          77.245000    23.500000
# 50%    36932.000000    45.000000          91.885000    28.100000
# 75%    54682.000000    61.000000         114.090000    33.100000
# max    72940.000000    82.000000         271.740000    97.600000

# %%
# Data Cleaning
df.nunique()
# Out:
# id                   5110
# gender                  3
# age                    83
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
#Removing trailing whitespace
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# We can have a look at the proportion of missing data
df['bmi'].isnull().mean()
# Out:
# 0.03933463796477495

# %%
df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67         False           True          Yes
# 1  51676  Female   61         False          False          Yes
# 2  31112    Male   80         False           True          Yes
# 3  60182  Female   49         False          False          Yes
# 4   1665  Female   79          True          False          Yes
#
#        work_type residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
df.describe()
# Out:
#                  id          age  avg_glucose_level          bmi
# count   5110.000000  5110.000000        5110.000000  4909.000000
# mean   36517.829354    43.215264         106.147677    28.893237
# std    21161.721625    22.633866          45.283560     7.854067
# min       67.000000     0.000000          55.120000    10.300000
# 25%    17741.250000    25.000000          77.245000    23.500000
# 50%    36932.000000    45.000000          91.885000    28.100000
# 75%    54682.000000    61.000000         114.090000    33.100000
# max    72940.000000    82.000000         271.740000    97.600000

# %%
# BMI  column imputation with mean value
df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
df
# We used mean value because:
    #1. The variable is numerical
    #2. The variable is randomly distributed across the dataset
    #3. Filling missing values with the mean is a simple and computationally efficient method. It is easy to implement, and it doesn't introduce complexities in the data
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67         False           True          Yes
# 1     51676  Female   61         False          False          Yes
# 2     31112    Male   80         False           True          Yes
# 3     60182  Female   49         False          False          Yes
# 4      1665  Female   79          True          False          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80          True          False          Yes
# 5106  44873  Female   81         False          False          Yes
# 5107  19723  Female   35         False          False          Yes
# 5108  37544    Male   51         False          False          Yes
# 5109  44679  Female   44         False          False          Yes
#
#           work_type residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# 1     Self-employed          Rural             202.21  28.893237
# 2           Private          Rural             105.92  32.500000
# 3           Private          Urban             171.23  34.400000
# 4     Self-employed          Rural             174.12  24.000000
# ...             ...            ...                ...        ...
# 5105        Private          Urban              83.75  28.893237
# 5106  Self-employed          Urban             125.20  40.000000
# 5107  Self-employed          Rural              82.99  30.600000
# 5108        Private          Rural             166.29  25.600000
# 5109       Govt_job          Urban              85.28  26.200000
#
#        smoking_status  stroke
# 0     formerly smoked    True
# 1        never smoked    True
# 2        never smoked    True
# 3              smokes    True
# 4        never smoked    True
# ...               ...     ...
# 5105     never smoked   False
# 5106     never smoked   False
# 5107     never smoked   False
# 5108  formerly smoked   False
# 5109          Unknown   False
#
# [5110 rows x 12 columns]

# %%
df.head()
df.isna().any()
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# residence_type       False
# avg_glucose_level    False
# bmi                  False
# smoking_status       False
# stroke               False
# dtype: bool

# %%
# Checking and handling duplicates
df.duplicated()
# Check for duplicates sum per  in the dataframe
df.duplicated().sum()
# Out:
# 0

# %%
# Detecting and handling Outliers
# Using boxplot to visualize Outliers
sns.boxplot(data=df)
# We decided not to drop the outliers

# Dropped the id column to better visualize boxplot
df= df.drop(['id'],axis=1)
df
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       Male   67         False           True          Yes        Private
# 1     Female   61         False          False          Yes  Self-employed
# 2       Male   80         False           True          Yes        Private
# 3     Female   49         False          False          Yes        Private
# 4     Female   79          True          False          Yes  Self-employed
# ...      ...  ...           ...            ...          ...            ...
# 5105  Female   80          True          False          Yes        Private
# 5106  Female   81         False          False          Yes  Self-employed
# 5107  Female   35         False          False          Yes  Self-employed
# 5108    Male   51         False          False          Yes        Private
# 5109  Female   44         False          False          Yes       Govt_job
#
#      residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0             Urban             228.69  36.600000  formerly smoked    True
# 1             Rural             202.21  28.893237     never smoked    True
# 2             Rural             105.92  32.500000     never smoked    True
# 3             Urban             171.23  34.400000           smokes    True
# 4             Rural             174.12  24.000000     never smoked    True
# ...             ...                ...        ...              ...     ...
# 5105          Urban              83.75  28.893237     never smoked   False
# 5106          Urban             125.20  40.000000     never smoked   False
# 5107          Rural              82.99  30.600000     never smoked   False
# 5108          Rural             166.29  25.600000  formerly smoked   False
# 5109          Urban              85.28  26.200000          Unknown   False
#
# [5110 rows x 11 columns]

# %%
# Feature Scaling
from sklearn import preprocessing
import numpy as np

a=np.random.random((1,4))
a=a*20
print("df=",a)

# normalize the df attributes
normalized = preprocessing.normalize(a)
print("Normalized_df=", normalized)
# Out:
# df= [[ 2.54102777  8.10426443  7.52200578 15.7520868 ]]
# Normalized_df= [[0.13089655 0.41747683 0.38748281 0.81144086]]

# %%
x_array = np.array([0,2,3,5,6,7,4,8,7,6,10])
normalized_arr = preprocessing.normalize([x_array])
print(x_array)
print(normalized_arr)
# Out:
# [ 0  2  3  5  6  7  4  8  7  6 10]
# [[0.         0.10153462 0.15230192 0.25383654 0.30460385 0.35537116
#   0.20306923 0.40613847 0.35537116 0.30460385 0.50767308]]

# %%
# Standardization
# Import standard scaler from sklearn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Slice the data using the columns age, RM
sliced_data = df[['age','avg_glucose_level','bmi']]
print(sliced_data)

# Once we have the data ready, we can use the StandardScaler() class and
# its methods (from sklearn library) to standardize the data:
sliced_data2= scaler.fit_transform(sliced_data)
sliced_data2
# Out:
#       age  avg_glucose_level        bmi
# 0      67             228.69  36.600000
# 1      61             202.21  28.893237
# 2      80             105.92  32.500000
# 3      49             171.23  34.400000
# 4      79             174.12  24.000000
# ...   ...                ...        ...
# 5105   80              83.75  28.893237
# 5106   81             125.20  40.000000
# 5107   35              82.99  30.600000
# 5108   51             166.29  25.600000
# 5109   44              85.28  26.200000
#
# [5110 rows x 3 columns]
# array([[ 1.05095010e+00,  2.70637544e+00,  1.00123401e+00],
#        [ 7.85834663e-01,  2.12155854e+00,  4.61555355e-16],
#        [ 1.62536687e+00, -5.02830130e-03,  4.68577254e-01],
#        ...,
#        [-3.62998890e-01, -5.11442636e-01,  2.21736316e-01],
#        [ 3.43975604e-01,  1.32825706e+00, -4.27845098e-01],
#        [ 3.46742627e-02, -4.60867458e-01, -3.49895329e-01]])

# %%
# As you can see, the above code returned an array,
# so the last step would be to convert it to dataframe
standardized_df = pd.DataFrame(sliced_data2, columns=sliced_data.columns)
print(standardized_df)
# Out:
#            age  avg_glucose_level           bmi
# 0     1.050950           2.706375  1.001234e+00
# 1     0.785835           2.121559  4.615554e-16
# 2     1.625367          -0.005028  4.685773e-01
# 3     0.255604           1.437358  7.154182e-01
# 4     1.581181           1.501184 -6.357112e-01
# ...        ...                ...           ...
# 5105  1.625367          -0.494658  4.615554e-16
# 5106  1.669553           0.420775  1.442949e+00
# 5107 -0.362999          -0.511443  2.217363e-01
# 5108  0.343976           1.328257 -4.278451e-01
# 5109  0.034674          -0.460867 -3.498953e-01
#
# [5110 rows x 3 columns]

# %%
# END OF DATA CLEANING

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67         False           True          Yes        Private
# 1  Female   61         False          False          Yes  Self-employed
# 2    Male   80         False           True          Yes        Private
# 3  Female   49         False          False          Yes        Private
# 4  Female   79          True          False          Yes  Self-employed
#
#   residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0          Urban             228.69  36.600000  formerly smoked    True
# 1          Rural             202.21  28.893237     never smoked    True
# 2          Rural             105.92  32.500000     never smoked    True
# 3          Urban             171.23  34.400000           smokes    True
# 4          Rural             174.12  24.000000     never smoked    True

# %%
cleaned_df = df

# %%
cleaned_df
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       Male   67         False           True          Yes        Private
# 1     Female   61         False          False          Yes  Self-employed
# 2       Male   80         False           True          Yes        Private
# 3     Female   49         False          False          Yes        Private
# 4     Female   79          True          False          Yes  Self-employed
# ...      ...  ...           ...            ...          ...            ...
# 5105  Female   80          True          False          Yes        Private
# 5106  Female   81         False          False          Yes  Self-employed
# 5107  Female   35         False          False          Yes  Self-employed
# 5108    Male   51         False          False          Yes        Private
# 5109  Female   44         False          False          Yes       Govt_job
#
#      residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0             Urban             228.69  36.600000  formerly smoked    True
# 1             Rural             202.21  28.893237     never smoked    True
# 2             Rural             105.92  32.500000     never smoked    True
# 3             Urban             171.23  34.400000           smokes    True
# 4             Rural             174.12  24.000000     never smoked    True
# ...             ...                ...        ...              ...     ...
# 5105          Urban              83.75  28.893237     never smoked   False
# 5106          Urban             125.20  40.000000     never smoked   False
# 5107          Rural              82.99  30.600000     never smoked   False
# 5108          Rural             166.29  25.600000  formerly smoked   False
# 5109          Urban              85.28  26.200000          Unknown   False
#
# [5110 rows x 11 columns]

# %%
# Exporting data
df.to_csv('cleaned_df.csv')

# %%
# a bar graph showing distibution of work_type with respect to stroke
fig, ax=plt.subplots()
cleaned_df.groupby('work_type')[['stroke']].sum().plot.bar(ax=ax)
ax.set_title("Distibution of work_type with respect to stroke")
ax.set_ylabel("Number of people");
# Out:
# Text(0, 0.5, 'Number of people')

# %%
 #a bar graph showing distibution of gender with respect to stroke
fig, ax=plt.subplots()
cleaned_df.groupby('gender')[['stroke']].sum().plot.bar(ax=ax)
ax.set_title("Distibution of gender with respect to stroke")
ax.set_ylabel("Number of people");

# %%
 #a bar graph showing distibution of smoking status with respect to stroke
fig, ax=plt.subplots()
cleaned_df.groupby('smoking_status')[['stroke']].sum().plot.bar(ax=ax)
ax.set_title("Distibution of smoking_status with respect to stroke")
ax.set_ylabel("Number of people");

# %%
#Working with cleaned dataset
import pandas as pd
import matplotlib.pyplot as plt

# Loading CleanedData
df2 = pd.read_csv('cleaned_df.csv')
df2.head()
# Out:
#    Unnamed: 0  gender  age  hypertension  heart_disease ever_married  \
# 0           0    Male   67         False           True          Yes
# 1           1  Female   61         False          False          Yes
# 2           2    Male   80         False           True          Yes
# 3           3  Female   49         False          False          Yes
# 4           4  Female   79          True          False          Yes
#
#        work_type residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked    True
# 1     never smoked    True
# 2     never smoked    True
# 3           smokes    True
# 4     never smoked    True

# %%
# checking the shape
df2.shape
# Out:
# (5110, 12)

# %%
# Checking distribution of avg_glucose_level across different ages.
import seaborn as sns
sns.displot(df2, x='age', y= 'avg_glucose_level')

# %% [markdown]
# # The average glucose level lies between 50 to less than 150, and is distributed almost uniformly across all ages

# %%
# Checking bmi distribution across different ages.
sns.jointplot(df2, x='age', y= 'bmi')
# Out:
# C:\Users\Dee\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-5219e540a0c1> in <module>
#       1 # Checking bmi distribution across different ages.
# ----> 2 sns.jointplot(df2, x='age', y= 'bmi')
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2054
#    2055     # Initialize the JointGrid object
# -> 2056     grid = JointGrid(
#    2057         data=data, x=x, y=y, hue=hue,
#    2058         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1589
#    1590         # Process the input variables
# -> 1591         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1592         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1593
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `bmi` for parameter `y`

# %% [markdown]
# # The bmi displays a normal distribution and majority of patients' bmi lies between 20 and 40.

# %%
#Cheking data structure
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   int64
#  3   hypertension       5110 non-null   bool
#  4   heart_disease      5110 non-null   bool
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   bool
# dtypes: bool(3), float64(2), int64(2), object(5)
# memory usage: 374.4+ KB
#         Unnamed: 0          age  avg_glucose_level          bmi
# count  5110.000000  5110.000000        5110.000000  5110.000000
# mean   2554.500000    43.215264         106.147677    28.893237
# std    1475.274268    22.633866          45.283560     7.698018
# min       0.000000     0.000000          55.120000    10.300000
# 25%    1277.250000    25.000000          77.245000    23.800000
# 50%    2554.500000    45.000000          91.885000    28.400000
# 75%    3831.750000    61.000000         114.090000    32.800000
# max    5109.000000    82.000000         271.740000    97.600000

# %%
#Explore the correlation between hypertension, heart disease and stroke
import seaborn as sns

#Exploring the correlation matrix
correlation_matrix = df2[['hypertension', 'heart_disease', 'stroke']].corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt='.2f', linewidths=.5)
plt.title('Correlation between Hypertension, Heart Disease, and Stroke')
plt.show()

# %%
#Correlation outputs interpretation
# There is a weak positive correlation between clients who have hypertension,heart disease and stroke as seen from the correlation coefficients 
# of 0.13,0.11 and 0.13 respectively.
# This shows that someone who has hypertension has a low likelihood of having heart disease or stroke and vice versa.
