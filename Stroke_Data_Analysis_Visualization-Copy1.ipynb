# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading Data
df = pd.read_csv(r'C:\Users\DANIEL\Desktop\Flatiron\stroke_data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# Checking last three rows
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
# Checking data types
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# ...

# %%
# Cleaning data type 
df['age'] = df['age'].astype(int)
df['age'].dtypes
df['hypertension'] = df['hypertension'].astype(bool)
df['heart_disease'] = df['heart_disease'].astype(bool)
df['stroke'] = df['stroke'].astype(bool)
df.dtypes
# Out:
# id                     int64
# gender                object
# age                    int32
# hypertension            bool
# heart_disease           bool
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                  bool
# dtype: object

# %%
#Changing all characters to lowercase
df.columns= df.columns.str.lower()
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# Checking dimension of the dataset
df.shape
# Out:
# (5110, 12)

# %%
# Checking for missingness
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
# Checking sum of missingness in the columns
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Checking if any of the columns has  missing values and returns True if present and False if not
df.isna().any()
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# residence_type       False
# avg_glucose_level    False
# bmi                   True
# smoking_status       False
# stroke               False
# dtype: bool

# %%
# To check the summary statistics of the data
df.describe()
# Out:
#                  id          age  avg_glucose_level          bmi
# count   5110.000000  5110.000000        5110.000000  4909.000000
# mean   36517.829354    43.215264         106.147677    28.893237
# std    21161.721625    22.633866          45.283560     7.854067
# min       67.000000     0.000000          55.120000    10.300000
# 25%    17741.250000    25.000000          77.245000    23.500000
# 50%    36932.000000    45.000000          91.885000    28.100000
# 75%    54682.000000    61.000000         114.090000    33.100000
# max    72940.000000    82.000000         271.740000    97.600000

# %%
# Data Cleaning
df.nunique()
# Out:
# id                   5110
# gender                  3
# age                    83
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
#Removing trailing whitespace
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# We can have a look at the proportion of missing data
df['bmi'].isnull().mean()
# Out:
# 0.03933463796477495

# %%
df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67         False           True          Yes
# 1  51676  Female   61         False          False          Yes
# 2  31112    Male   80         False           True          Yes
# 3  60182  Female   49         False          False          Yes
# 4   1665  Female   79          True          False          Yes
#
#        work_type residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
df.describe()
# Out:
#                  id          age  avg_glucose_level          bmi
# count   5110.000000  5110.000000        5110.000000  4909.000000
# mean   36517.829354    43.215264         106.147677    28.893237
# std    21161.721625    22.633866          45.283560     7.854067
# min       67.000000     0.000000          55.120000    10.300000
# 25%    17741.250000    25.000000          77.245000    23.500000
# 50%    36932.000000    45.000000          91.885000    28.100000
# 75%    54682.000000    61.000000         114.090000    33.100000
# max    72940.000000    82.000000         271.740000    97.600000

# %%
# BMI  column imputation with mean value
df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
df
# We used mean value because:
    #1. The variable is numerical
    #2. The variable is randomly distributed across the dataset
    #3. Filling missing values with the mean is a simple and computationally efficient method. It is easy to implement, and it doesn't introduce complexities in the data
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67         False           True          Yes
# 1     51676  Female   61         False          False          Yes
# 2     31112    Male   80         False           True          Yes
# 3     60182  Female   49         False          False          Yes
# 4      1665  Female   79          True          False          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80          True          False          Yes
# 5106  44873  Female   81         False          False          Yes
# 5107  19723  Female   35         False          False          Yes
# 5108  37544    Male   51         False          False          Yes
# 5109  44679  Female   44         False          False          Yes
#
#           work_type residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

df_a = df[['age', 'avg_glucose_level', 'bmi']]

# Let's generate some data using randn() where it is a normal distribution and, mean = 0, sd = 1
#generates an array of 1000 random values sampled from a standard normal distribution (mean=0, standard deviation=1)
df_a = np.random.randn(1000)

# Ploting the histogram, probability density function (PDF) 
plt.hist(df_a, bins= 100, density=True, alpha= 1, color='yellow', edgecolor='black')

# TITLE - LABELS
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Plot of Distribution')

#SHOW PLOT FUNC
plt.show()

# %%
#distribution of age using a kernel density plot
import seaborn as sns
df_b = df['age']
sns.kdeplot(df_b, shade=True)

#distribution of age using a kernel density plot
import seaborn as sns
df_d = df['bmi']
sns.kdeplot(df_d, shade=True)

#distribution of glucose levels using a kernel density plot
import seaborn as sns
df_c = df['avg_glucose_level']
sns.kdeplot(df_c, shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
#distribution of glucose levels using a kernel density plot
import seaborn as sns
df_a = df['age']
sns.kdeplot(df_a, shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
#distribution of glucose levels using a kernel density plot
import seaborn as sns
df_b = df['bmi']
sns.kdeplot(df_b, shade=True)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
#distribution of glucose levels using a kernel density plot
import seaborn as sns
df_c = df['avg_glucose_level']
sns.kdeplot(df_c, shade=True)
# Out:
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='Density'>

# %%
np.isnan(float(str(np.nan)))
# Out:
# True

# %%
#SCATTER PLOT VISUALIZATION OF THE RLSHP BETWEEN BMI AND AGE
sns.scatterplot(x="age", y='bmi', data = df, hue = "residence_type", hue_order = ('Urban', 'Rural'), alpha= 1, color='red', edgecolor='black' );
plt.title('AGE AND BMI AND RESIDENCE TYPE')
plt.show()

#SCATTER PLOT VISUALIZATION OF THE RLSHP BETWEEN AGE AND GLUCODE
sns.scatterplot(x = "age", y = "avg_glucose_level", data = df, hue = "residence_type", hue_order = ('Urban', 'Rural'))
plt.title("AGE AND GLUCOSE LEVELS AND RESIDENCE TYPE")
plt.show()

#RLSHP BETWEEN GENDER GLUCOSE AND BMI
sns.scatterplot(x=df['bmi'], y=df['avg_glucose_level'], hue=df['gender'], style=df['gender'])
plt.title('BMI AND GLUCOSE LEVELS AND GENDER')
plt.show()

#RLSHP BETWEEN AGE GENDER AND BMI
sns.scatterplot(x=df['age'], y=df['bmi'], hue=df['gender'], style=df['gender'])
plt.title('AGE, BMI AND GENDER')
plt.show()

# %%
df.head()
df.isna().any()
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# residence_type       False
# avg_glucose_level    False
# bmi                  False
# smoking_status       False
# stroke               False
# dtype: bool

# %%
# Checking and handling duplicates
df.duplicated()
# Check for duplicates sum per  in the dataframe
df.duplicated().sum()
# Out:
# 0

# %%
# Detecting and handling Outliers
# Using boxplot to visualize Outliers

# We decided not to drop the outliers

# Dropped the id column to better visualize boxplot
df1 = df.drop(df.columns[0],axis=1)
sns.boxplot(data=df1)
df1
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       Male   67         False           True          Yes        Private
# 1     Female   61         False          False          Yes  Self-employed
# 2       Male   80         False           True          Yes        Private
# 3     Female   49         False          False          Yes        Private
# 4     Female   79          True          False          Yes  Self-employed
# ...      ...  ...           ...            ...          ...            ...
# 5105  Female   80          True          False          Yes        Private
# 5106  Female   81         False          False          Yes  Self-employed
# 5107  Female   35         False          False          Yes  Self-employed
# 5108    Male   51         False          False          Yes        Private
# 5109  Female   44         False          False          Yes       Govt_job
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# CREATING SAMPLE DATA FRAME SERIES WITH UPPER BOUNDS
df1 = pd.DataFrame({
    'age': [10, 25, 40, 55, 70, 85,100],
    'avg_glucose_level': [10,150, 200, 250, 300, 350, 400],
    'bmi': [15, 30, 60, 120, 220, 320, 420],
})

#ADD LABELS AND TITLE
plt.xlabel ('Variables')
plt.ylabel('Values') 
plt.title('Boxplot of Variables Age, Avg Glucose Levels(*10) and BMI', loc = "right")

# CREATE BOXPLOT
df1.boxplot(column=['age', 'avg_glucose_level', 'bmi'])

#PLOT FUNC
plt.show()

#adding color turned out to be quite difficult assist if you can

# %%
#LOAD CSV
bar = pd.read_csv(r"C:\Users\DANIEL\Desktop\Flatiron\stroke_data.csv")
df = pd.DataFrame(bar)

age = df['age']
bmi = df['bmi']
glucose = df['avg_glucose_level']

#SIZE DEFN
fig = plt.figure(figsize =(10, 7))

#PLOT PROCESS
plt.bar(age, bmi)
plt.xlabel ('Age')
plt.ylabel('BMI') 
plt.title('Bargraph of Variables:Age & BMI', loc = "right")

# PLOT FUNCTION
plt.show()

# %%
# LOADING CSV
bar = pd.read_csv(r"C:\Users\DANIEL\Desktop\Flatiron\stroke_data.csv")
df = pd.DataFrame(bar)

age = df['age']
bmi = df['bmi']
glucose = df['avg_glucose_level']

# SIZE DEF
fig = plt.figure(figsize =(10, 7))

#PLOTTING PROCESS
plt.bar(age, glucose)
plt.xlabel ('Age')
plt.ylabel('avg_glucose_level') 
plt.title('Bargraph of Variables:Age & Glucose', loc = "right")

#PLOT FUNCTION
plt.show()

# %%
#LOADING CSV
bar = pd.read_csv(r"C:\Users\DANIEL\Desktop\Flatiron\stroke_data.csv")
df = pd.DataFrame(bar)

age = df['age']
bmi = df['bmi']
glucose = df['avg_glucose_level']

# DEFINE SIZE
fig = plt.figure(figsize =(10, 7))

# PLOT THE BAR GRAPH
plt.bar(glucose, bmi)
plt.xlabel ('avg_glucose_level')
plt.ylabel('BMI') 
plt.title('Bargraph of Variables:BMI & Glucose Levels', loc = "right")

#PLOT FUNVCTION
plt.show()

# %%
#bar graph showing number of  people with the disease grouped by age_categories
fig, ax = plt.subplots(figsize=(20,5))

df.groupby('age')[['hypertension', 'stroke', 'heart_disease']].sum().plot(kind = 'bar', ax=ax, edgecolor ="black")
ax.set_title('Number of  people with Hypertension, Stroke and Heart Diseasedisease by their Age')
ax.set_ylabel('Population')
plt.xticks(rotation=0);

# %%
#horizontal bar graph showing number of people with the disease by type of residence
fig, ax = plt.subplots()

df.groupby('Residence_type')[['hypertension', 'stroke', 'heart_disease']].sum().plot.barh(ax=ax)
ax.set_title('#Number of people with Hypertension, Stroke and Heart Disease by their Residence Type')
ax.set_xlabel('Populations');

# %%
# Feature Scaling
from sklearn import preprocessing
import numpy as np

a=np.random.random((1,4))
a=a*20
print("df=",a)

# normalize the df attributes
normalized = preprocessing.normalize(a)
print("Normalized_df=", normalized)
# Out:
# df= [[ 2.26023632 18.22543782  3.70324072  2.29404614]]
# Normalized_df= [[0.11974993 0.96560472 0.19620197 0.12154121]]

# %%
x_array = np.array([0,2,3,5,6,7,4,8,7,6,10])
normalized_arr = preprocessing.normalize([x_array])
print(x_array)
print(normalized_arr)
# Out:
# [ 0  2  3  5  6  7  4  8  7  6 10]
# [[0.         0.10153462 0.15230192 0.25383654 0.30460385 0.35537116
#   0.20306923 0.40613847 0.35537116 0.30460385 0.50767308]]

# %%
# Standardization
# Import standard scaler from sklearn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Slice the data using the columns age, RM
sliced_data = df[['age','avg_glucose_level','bmi']]
print(sliced_data)

# Once we have the data ready, we can use the StandardScaler() class and
# its methods (from sklearn library) to standardize the data:
sliced_data2= scaler.fit_transform(sliced_data)
sliced_data2
# Out:
#        age  avg_glucose_level   bmi
# 0     67.0             228.69  36.6
# 1     61.0             202.21   NaN
# 2     80.0             105.92  32.5
# 3     49.0             171.23  34.4
# 4     79.0             174.12  24.0
# ...    ...                ...   ...
# 5105  80.0              83.75   NaN
# 5106  81.0             125.20  40.0
# 5107  35.0              82.99  30.6
# 5108  51.0             166.29  25.6
# 5109  44.0              85.28  26.2
#
# [5110 rows x 3 columns]
# array([[ 1.05143428,  2.70637544,  0.98134488],
#        [ 0.78607007,  2.12155854,         nan],
#        [ 1.62639008, -0.0050283 ,  0.45926914],
#        ...,
#        [-0.36384151, -0.51144264,  0.21733161],
#        [ 0.34379639,  1.32825706, -0.41934612],
#        [ 0.03420481, -0.46086746, -0.34294479]])

# %%
# As you can see, the above code returned an array,
# so the last step would be to convert it to dataframe
standardized_df = pd.DataFrame(sliced_data2, columns=sliced_data.columns)
print(standardized_df)
# Out:
#            age  avg_glucose_level       bmi
# 0     1.051434           2.706375  0.981345
# 1     0.786070           2.121559       NaN
# 2     1.626390          -0.005028  0.459269
# 3     0.255342           1.437358  0.701207
# 4     1.582163           1.501184 -0.623083
# ...        ...                ...       ...
# 5105  1.626390          -0.494658       NaN
# 5106  1.670617           0.420775  1.414286
# 5107 -0.363842          -0.511443  0.217332
# 5108  0.343796           1.328257 -0.419346
# 5109  0.034205          -0.460867 -0.342945
#
# [5110 rows x 3 columns]

# %%
# END OF DATA CLEANING

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
cleaned_df = df

# %%
cleaned_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# Exporting data
df.to_csv('cleaned_df.csv')
